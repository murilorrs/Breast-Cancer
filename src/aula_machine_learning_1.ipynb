# %% [markdown]
# # Breast Cancer Dataset
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html#sklearn.datasets.load_breast_cancer

# %% [markdown]
# #MLPClassifier

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier

# %%
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %% [markdown]
# https://scikit-learn.org/stable/datasets/toy_dataset.html

# %%
X = df.drop('target', axis=1)
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=41)

# %%
X_train.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 475        12.83         15.73           82.89      506.9          0.09040
# 298        14.26         18.17           91.22      633.1          0.06576
# 220        13.65         13.16           87.88      568.9          0.09646
# 549        10.82         24.21           68.89      361.6          0.08192
# 567        20.60         29.33          140.10     1265.0          0.11780
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 475           0.08269         0.05835              0.03078         0.1705
# 298           0.05220         0.02475              0.01374         0.1635
# 220           0.08711         0.03888              0.02563         0.1360
# 549           0.06602         0.01548              0.00816         0.1976
# 567           0.27700         0.35140              0.15200         0.2397
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 475                 0.05913  ...         14.09          19.35
# 298                 0.05586  ...         16.22          25.26
# 220                 0.06344  ...         15.34          16.35
# 549                 0.06328  ...         13.03          31.45
# 567                 0.07016  ...         25.74          39.42
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 475            93.22       605.8           0.13260             0.2610
# 298           105.80       819.7           0.09445             0.2167
# 220            99.71       706.2           0.13110             0.2474
# 549            83.90       505.6           0.12040             0.1633
# 567           184.60      1821.0           0.16500             0.8681
#
#      worst concavity  worst concave points  worst symmetry  \
# 475          0.34760               0.09783          0.3006
# 298          0.15650               0.07530          0.2636
# 220          0.17590               0.08056          0.2380
# 549          0.06194               0.03264          0.3059
# 567          0.93870               0.26500          0.4087
#
#      worst fractal dimension
# 475                  0.07802
# 298                  0.07676
# 220                  0.08718
# 549                  0.07626
# 567                  0.12400
#
# [5 rows x 30 columns]

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
df_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
df_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)

# %%
df_train_scaled.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0    -0.364987     -0.834638       -0.370442  -0.422655        -0.414374
# 1     0.052088     -0.267009       -0.017729  -0.046333        -2.194288
# 2    -0.125825     -1.432510       -0.159153  -0.237774         0.023381
# 3    -0.951226      1.138106       -0.963237  -0.855932        -1.026942
# 4     1.901220      2.329197        2.051973   1.837960         1.564913
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0         -0.408926       -0.380271            -0.456438      -0.379767
# 1         -0.994345       -0.811747            -0.902450      -0.639652
# 2         -0.324060       -0.630296            -0.591236      -1.660629
# 3         -0.728996       -0.930789            -1.048503       0.626360
# 4          3.321893        3.382945             2.716423       2.189384
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0               -0.534265  ...     -0.453655      -1.061777        -0.419853
# 1               -1.012387  ...     -0.004653      -0.093985        -0.036730
# 2                0.095920  ...     -0.190156      -1.553042        -0.222201
# 3                0.072526  ...     -0.677102       0.919659        -0.703694
# 4                1.078482  ...      2.002153       2.224786         2.363120
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0   -0.488824         -0.003816           0.029583         0.347072
# 1   -0.101754         -1.670457          -0.251139        -0.569570
# 2   -0.307142         -0.069345          -0.056598        -0.476515
# 3   -0.670145         -0.536791          -0.589527        -1.023143
# 4    1.710186          1.411628           3.876684         3.182380
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0             -0.259673        0.171929                -0.353263
# 1             -0.604303       -0.441127                -0.423417
# 2             -0.523844       -0.865296                 0.156741
# 3             -1.256851        0.259745                -0.451255
# 4              2.297439        1.963047                 2.206779
#
# [5 rows x 30 columns]

# %%
model = MLPClassifier(hidden_layer_sizes=(50,), 
                      activation='logistic',
                      learning_rate='adaptive', 
                      max_iter=200, 
                      random_state=42)

# %%
model.fit(X_train_scaled, y_train)
# Out:
# C:\Users\muril\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(activation='logistic', hidden_layer_sizes=(50,),
#               learning_rate='adaptive', random_state=42)

# %%
y_pred = model.predict(X_test_scaled)

# %%
X_test_scaled
# Out:
# array([[-0.43790257, -0.21350264, -0.50001024, ..., -1.62194722,
#         -0.65818251, -1.11659911],
#        [ 0.19791867, -1.06494654,  0.13682124, ...,  0.15746166,
#          0.34259051, -0.13890569],
#        [ 0.16291934, -0.94862907,  0.17492951, ...,  0.38079026,
#          0.41218069,  0.02033139],
#        ...,
#        [-0.16665773, -0.09951152, -0.14983761, ...,  0.46645055,
#         -0.39142016, -0.41784897],
#        [-0.88122747, -0.51127537, -0.86330905, ..., -0.30082087,
#         -0.20253254,  1.80590246],
#        [-0.06165972, -0.72297317, -0.13205375, ..., -0.90625553,
#         -0.89512049, -0.73687991]])

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 1.0

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=X_train)
plt.show()

# %%
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(X_train))
outliers = np.where(z_scores > 3)
print(outliers)
# Out:
# (array([  4,   4,   4,   4,   6,  11,  14,  14,  14,  14,  14,  14,  14,
#         16,  18,  19,  24,  24,  26,  26,  36,  36,  36,  36,  36,  36,
#         36,  46,  46,  46,  52,  52,  52,  55,  55,  63,  70,  70,  70,
#         76,  87,  87,  87,  87,  87,  87,  87,  87,  87,  91,  91,  91,
#         91,  92,  92,  92,  94,  94,  99, 108, 108, 108, 108, 108, 108,
#        108, 108, 108, 113, 113, 113, 113, 113, 113, 131, 136, 137, 137,
#        138, 138, 138, 153, 159, 164, 164, 164, 169, 177, 177, 197, 197,
#        218, 236, 240, 240, 240, 250, 250, 258, 258, 258, 258, 259, 259,
#        259, 272, 281, 282, 282, 284, 284, 284, 284, 289, 298, 299, 299,
#        299, 299, 327, 331, 331, 331, 331, 331, 349, 349, 349, 349, 349,
#        379, 379, 380, 380, 383, 393, 393, 393, 407, 412, 412, 412, 412,
#        412, 412, 415, 415, 415, 415, 415, 415, 415, 421, 429, 429, 429,
#        429, 429, 429, 435, 435, 435, 435, 435, 435, 435, 435, 435, 435,
#        435, 435, 435, 435, 435, 436, 442, 442, 448, 448, 448, 448, 448],
#       dtype=int64), array([ 5,  6, 25, 26, 28, 11, 15, 16, 18, 19, 25, 28, 29, 28,  8, 14, 25,
#        29,  5, 25,  3, 10, 12, 13, 20, 22, 23,  5, 12, 13, 24, 25, 29, 19,
#        29, 28, 25, 26, 29, 25,  5,  6,  7, 10, 12, 13, 15, 22, 26, 10, 13,
#        20, 23,  8, 18, 28, 28, 29,  9,  0,  2,  3,  6,  7, 13, 20, 22, 23,
#        10, 13, 20, 21, 22, 23, 11,  4, 15, 17, 10, 12, 13, 12, 26,  9, 14,
#        19,  1,  1, 21, 16, 19, 11, 19, 15, 16, 19, 10, 12,  3, 13, 20, 23,
#         9, 16, 19,  3, 19,  3,  6,  9, 14, 15, 19, 23, 11, 15, 16, 17, 26,
#        24, 14, 15, 16, 17, 19,  0,  2,  3, 22, 23, 15, 19, 10, 13, 28, 10,
#        12, 18, 11,  5,  6,  8, 12, 18, 28,  0,  2,  3,  7, 20, 22, 23, 26,
#        11, 12, 15, 17, 18, 19,  2,  3,  4,  5,  6,  7,  8, 10, 11, 12, 13,
#        14, 15, 16, 18, 14,  4, 29,  3, 13, 20, 22, 23], dtype=int64))
